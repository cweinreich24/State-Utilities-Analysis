# %%
import requests
import json
from pprint import pprint
from config import api_key
import matplotlib.pyplot as plt
import pandas as pd

# %%
states = ["IL", "OH", "CA", "AL", "NY", "AZ", "WA", "MA", "FL", "TX"]
fuels = ["COW", "NG", "WND", "SUN", "HYC", "NUC", "BIO"]
#state_fuels = []

#for state in states:
    #for fuel in fuels:
        #state_fuels.append(str(state) + " Date " + str(fuel))
        #state_fuels.append(str(state) + " Data " + str(fuel))
        
#df = pd.DataFrame(columns=state_fuels)
#df1 = pd.DataFrame(columns=state_fuels)

# 1.M  Indicates the utility
#cow = coal
#ng = natural gas
#wnd = wind
#sun = solar
#hyc = hydro electric conventional 
#nuc = nuclear
#bio = biomass

#IL - Illinois
#OH - Ohio
#CA - California
#AL - Alabama
#NY - New York
#AZ - Arizona
#WA - Washington
#MA - Massachusetts 
#FL - Florida

# %%
states = ["IL", "OH", "CA", "AL", "NY", "AZ", "WA", "MA", "FL", "TX"]

fuels = ["COW", "NG", "WND", "SUN", "HYC", "NUC", "GEO"]
df1 = pd.DataFrame()

for state in states:
    for fuel in fuels:
        try:
            df = pd.DataFrame()
            responses = []
            dates = []
            data = []
            query_url = "http://api.eia.gov/series/?api_key=" + api_key + "&series_id=ELEC.GEN."+ fuel + "-"+ state + "-99.M"
            responses.append(requests.get(query_url).json())
        #pprint(responses)
        #print('--------------------------------')
            for i in range(len(responses[0]['series'][0]["data"])):
                dates.append(responses[0]['series'][0]["data"][i][0])
                data.append(responses[0]['series'][0]["data"][i][1])
            df[str(state) + " Date " + str(fuel)] = dates
            df[str(state) + " Data " + str(fuel)] = data
            df1 = df1.join(df, how="outer")
        except:
            df[str(state) + " Date " + str(fuel)] = 0
            df[str(state) + " Data " + str(fuel)] = 0
            df1 = df1.join(df, how="outer")

# %%
states = ["IL", "OH", "CA", "AL", "NY", "AZ", "WA", "MA", "FL", "TX"]
fuels = ["COW", "NG", "WND", "SUN", "HYC", "NUC", "GEO"]

df1 = df1.fillna(0)
for state in states:
    for fuel in fuels:
        df1[str(state) + " Date " + str(fuel)] = df1["IL Date COW"]

# %%
df1.to_csv("generationoutput.csv")

# %%
fuels = ["HYC", "COW", "NG", "NUC"]
for state in states:
    for fuel in fuels:
        plt.plot(df1[str(state) + " Date " + str(fuel)],df1[str(state) + " Data " + str(fuel)])
    plt.legend(bbox_to_anchor =(1,1))
    
    plt.savefig(str(state) + "conventionalgeneration.png", dpi=500, bbox_inches='tight')
    plt.show()
    print(fuels)
# Out:
# ['HYC', 'COW', 'NG', 'NUC']
# ['HYC', 'COW', 'NG', 'NUC']
# ['HYC', 'COW', 'NG', 'NUC']
# ['HYC', 'COW', 'NG', 'NUC']
# ['HYC', 'COW', 'NG', 'NUC']
# ['HYC', 'COW', 'NG', 'NUC']
# ['HYC', 'COW', 'NG', 'NUC']
# ['HYC', 'COW', 'NG', 'NUC']
# ['HYC', 'COW', 'NG', 'NUC']
# ['HYC', 'COW', 'NG', 'NUC']

# %%
fuels = ["WND", "SUN", "HYC", "GEO"]
for state in states:
    for fuel in fuels:
        plt.plot(df1[str(state) + " Date " + str(fuel)],df1[str(state) + " Data " + str(fuel)])
    plt.legend(bbox_to_anchor =(1,1))
    
    plt.savefig(str(state) + "renewablegeneration.png", dpi=500, bbox_inches='tight')
    plt.show()
    print(fuels)
# Out:
# ['WND', 'SUN', 'HYC', 'GEO']
# ['WND', 'SUN', 'HYC', 'GEO']
# ['WND', 'SUN', 'HYC', 'GEO']
# ['WND', 'SUN', 'HYC', 'GEO']
# ['WND', 'SUN', 'HYC', 'GEO']
# ['WND', 'SUN', 'HYC', 'GEO']
# ['WND', 'SUN', 'HYC', 'GEO']
# ['WND', 'SUN', 'HYC', 'GEO']
# ['WND', 'SUN', 'HYC', 'GEO']
# ['WND', 'SUN', 'HYC', 'GEO']

# %%
fuels = ["COW", "NG", "WND", "SUN", "HYC", "NUC", "GEO"]
for state in states:
    for fuel in fuels:
        plt.plot(df1[str(state) + " Date " + str(fuel)],df1[str(state) + " Data " + str(fuel)])
    plt.legend(bbox_to_anchor =(1,1))
    
    plt.savefig(str(state) + "combinedgeneration.png", dpi=500, bbox_inches='tight')
    plt.show()
    print(fuels)
# Out:
# ['COW', 'NG', 'WND', 'SUN', 'HYC', 'NUC', 'GEO']
# ['COW', 'NG', 'WND', 'SUN', 'HYC', 'NUC', 'GEO']
# ['COW', 'NG', 'WND', 'SUN', 'HYC', 'NUC', 'GEO']
# ['COW', 'NG', 'WND', 'SUN', 'HYC', 'NUC', 'GEO']
# ['COW', 'NG', 'WND', 'SUN', 'HYC', 'NUC', 'GEO']
# ['COW', 'NG', 'WND', 'SUN', 'HYC', 'NUC', 'GEO']
# ['COW', 'NG', 'WND', 'SUN', 'HYC', 'NUC', 'GEO']
# ['COW', 'NG', 'WND', 'SUN', 'HYC', 'NUC', 'GEO']
# ['COW', 'NG', 'WND', 'SUN', 'HYC', 'NUC', 'GEO']
# ['COW', 'NG', 'WND', 'SUN', 'HYC', 'NUC', 'GEO']

# %%
fuels = ["COW", "NG", "WND", "SUN", "HYC", "NUC", "GEO"]
for state in states:
    for fuel in fuels:
        plt.plot(df1[str(state) + " Date " + str(fuel)],df1[str(state) + " Data " + str(fuel)])
plt.legend(bbox_to_anchor =(1,1))    
plt.savefig("AllStatescombinedgeneration.png", dpi=500, bbox_inches='tight')
plt.show()
print(fuels)
# Out:
# ['COW', 'NG', 'WND', 'SUN', 'HYC', 'NUC', 'GEO']
