# %%
import pandas as pd
import numpy as np

# %%
energy = "demand_forecasts.csv"

# %%
energy_df = pd.read_csv(energy)
energy_df.head()
# Out:
#        INTERVALSTARTTIME_GMT        INTERVALENDTIME_GMT  LOAD_TYPE  \
# 0  2016-04-15T23:00:00-00:00  2016-04-16T00:00:00-00:00          1
# 1  2016-04-16T05:00:00-00:00  2016-04-16T06:00:00-00:00          1
# 2  2016-04-15T14:00:00-00:00  2016-04-15T15:00:00-00:00          1
# 3  2016-04-15T18:00:00-00:00  2016-04-15T19:00:00-00:00          1
# 4  2016-04-15T19:00:00-00:00  2016-04-15T20:00:00-00:00          1
#
#        OPR_DT  OPR_HR  OPR_INTERVAL MARKET_RUN_ID TAC_AREA_NAME  \
# 0  2016-04-15      17             0           DAM    CA ISO-TAC
# 1  2016-04-15      23             0           DAM    CA ISO-TAC
# 2  2016-04-15       8             0           DAM    CA ISO-TAC
# 3  2016-04-15      12             0           DAM    CA ISO-TAC
# 4  2016-04-15      13             0           DAM    CA ISO-TAC
#
#                        LABEL   XML_DATA_ITEM  POS        MW EXECUTION_TYPE  \
# 0  Demand Forecast Day Ahead  SYS_FCST_DA_MW  2.0  24345.57            DAM
# ...
