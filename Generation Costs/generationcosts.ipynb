# %%
import pandas as pd
from pprint import pprint
import matplotlib.pyplot as plt

# %%
file = "generationcosts.csv"
df = pd.read_csv(file)

# %%
pprint(df.columns)
df
# Out:
# Index(['Technology', 'Gen Type', 'Technology Sub', 'Year',
#        'Levelized cost of energy', 'Fuel'],
#       dtype='object')
#                  Technology                Gen Type  \
# 0        Combustion Turbine      Combustion Turbine
# 1        Combustion Turbine      Combustion Turbine
# 2              Photovoltaic            Photovoltaic
# 3              Photovoltaic            Photovoltaic
# 4              Photovoltaic            Photovoltaic
# 5              Photovoltaic            Photovoltaic
# 6              Photovoltaic            Photovoltaic
# 7              Photovoltaic            Photovoltaic
# 8              Photovoltaic            Photovoltaic
# 9              Photovoltaic            Photovoltaic
# 10             Photovoltaic            Photovoltaic
# 11             Photovoltaic            Photovoltaic
# 12             Photovoltaic            Photovoltaic
# 13             Photovoltaic            Photovoltaic
# 14             Photovoltaic            Photovoltaic
# ...

# %%
#All the box plots on one graph. 
fig = df.boxplot("Levelized cost of energy", by="Technology", figsize=(30, 10))
plt.savefig("boxplots.png")

# %%
# df_nuclear = df.loc[df["Technology"]== "Nuclear"]
# df_hydro = df.loc[df["Technology"]== "Hydroelectric"]
# df_ng = df.loc[df["Technology"] == "Combined Cycle"]
# df_ngPeaker = df.loc[df["Technology"] == "Combustion Turbine"]
# df_solar = df.loc[df["Technology"] == "Photovoltaic"]
# df_coal = df.loc[df["Gen Type"] == "Coal"]
# df_wind = df.loc[df["Technology"] == "Onshore"]

# %%
# plt1 = plt.boxplot(df_nuclear["Levelized cost of energy"])
# plt.show()
# plt2 = plt.boxplot(df_hydro["Levelized cost of energy"])
# plt.show()
# plt3 = plt.boxplot(df_ng["Levelized cost of energy"])
# plt.show()
# plt4 = plt.boxplot(df_ngPeaker["Levelized cost of energy"])
# plt.show()
# plt5 = plt.boxplot(df_coal["Levelized cost of energy"])
# plt.show()
# plt5 = plt.boxplot(df_wind["Levelized cost of energy"])
# plt.show()
