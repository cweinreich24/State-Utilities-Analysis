# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json
import gmaps

# Google developer API key
from config import gkey

# %%
# Read CSV Files
wa_dams_df = pd.read_csv("WA_Dams.csv")
ca_dams_df = pd.read_csv("CA_Dams.csv")
wa_wind_df = pd.read_csv("WA_Wind.csv")
ca_wind_df = pd.read_csv("CA_Wind.csv")

# %%
# set up additional columns to hold information

wa_dams_df['lat']=""
wa_dams_df['lng']=""

ca_dams_df['lat']=""
ca_dams_df['lng']=""

wa_wind_df['lat']=""
wa_wind_df['lng']=""

# %%
### Loop Through Dams in WA ####

base_url = "https://maps.googleapis.com/maps/api/geocode/json"
params = {
    "location": "39.952583,-75.16522",  # philadelphia coords,
    "rankby": "distance",
    "type": "restaurant",
    "key": gkey,
}

# use iterrows to iterate through pandas dataframe
for index, row in wa_dams_df.iterrows():

    # get restaurant type from df
    restr_type = row['Name']

    # add keyword to params dict
    params["address"] = restr_type

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {restr_type}.")
    response = requests.get(base_url, params=params)
    
    dc_geo = response.json()
    
    try:
                
        wa_dams_df.loc[index, 'lat'] = dc_geo["results"][0]["geometry"]["location"]["lat"]
        wa_dams_df.loc[index, 'lng'] = dc_geo["results"][0]["geometry"]["location"]["lng"]

    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")


### Look Through Dams in CA ####

base_url = "https://maps.googleapis.com/maps/api/geocode/json"
params = {
    "location": "39.952583,-75.16522",  # philadelphia coords,
    "rankby": "distance",
    "type": "restaurant",
    "key": gkey,
}

# use iterrows to iterate through pandas dataframe
for index, row in ca_dams_df.iterrows():

    # get restaurant type from df
    restr_type = row['Name']

    # add keyword to params dict
    params["address"] = restr_type

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {restr_type}.")
    response = requests.get(base_url, params=params)
    
    dc_geo = response.json()
    
    try:
                
        ca_dams_df.loc[index, 'lat'] = dc_geo["results"][0]["geometry"]["location"]["lat"]
        ca_dams_df.loc[index, 'lng'] = dc_geo["results"][0]["geometry"]["location"]["lng"]

    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
# Out:
# Retrieving Results for Index 0: Bonneville Dam.
# ------------
# Retrieving Results for Index 1: Boundary Dam.
# ------------
# Retrieving Results for Index 2: Box Canyon Dam.
# ------------
# Retrieving Results for Index 3: Chief Joseph Dam.
# ------------
# Retrieving Results for Index 4: Diablo Dam.
# ------------
# Retrieving Results for Index 5: Electron Hydroelectric Project.
# ------------
# Retrieving Results for Index 6: Gorge Dam.
# ------------
# Retrieving Results for Index 7: Grand Coulee Dam.
# ------------
# Retrieving Results for Index 8: Ice Harbor Dam.
# ------------
# Retrieving Results for Index 9: Lake Chelan Dam.
# ------------
# Retrieving Results for Index 10: Little Goose Dam.
# ------------
# Retrieving Results for Index 11: Lower Baker Dam.
# ------------
# Retrieving Results for Index 12: Lower Granite Dam.
# ------------
# Retrieving Results for Index 13: Lower Monumental Dam.
# ------------
# Retrieving Results for Index 14: Merwin Dam.
# ------------
# Retrieving Results for Index 15: Priest Rapids Dam.
# ------------
# Retrieving Results for Index 16: Rock Island Dam.
# ------------
# Retrieving Results for Index 17: Rocky Reach Dam.
# ------------
# Retrieving Results for Index 18: Ross Dam.
# ------------
# Retrieving Results for Index 19: Snoqualmie Falls Hydroelectric Plant.
# ------------
# Retrieving Results for Index 20: Swift Dam.
# ------------
# Retrieving Results for Index 21: Upper Baker Dam.
# ------------
# Retrieving Results for Index 22: Wells Dam.
# ------------
# Retrieving Results for Index 23: Wanapum Dam.
# ------------
# Retrieving Results for Index 24: Yale Dam.
# ------------
# Retrieving Results for Index 25: Cushman No. 1 Dam.
# ------------
# Retrieving Results for Index 26: Cushman No. 2 Dam.
# ------------
# Retrieving Results for Index 27: Alder Dam.
# ------------
# Retrieving Results for Index 28: La Grande Dam.
# ------------
# Retrieving Results for Index 29: Mayfield Dam.
# ------------
# Retrieving Results for Index 30: Mossyrock Dam.
# ------------
# Retrieving Results for Index 31: Wynoochee Dam.
# ------------
# Retrieving Results for Index 0: Shasta Dam.
# ------------
# Retrieving Results for Index 1: Oroville Dam.
# ------------
# Retrieving Results for Index 2: New Bullards Bar Dam.
# ------------
# Retrieving Results for Index 3: New Melones Dam.
# ------------
# Retrieving Results for Index 4: White Rock Powerplant.
# ------------
# Retrieving Results for Index 5: New Don Pedro Dam.
# ------------
# Retrieving Results for Index 6: Eastwood Powerhouse.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 7: Folsom Dam.
# ------------
# Retrieving Results for Index 8: Mammoth Pool Dam.
# ------------
# Retrieving Results for Index 9: Spring Creek Powerplant*.
# ------------
# Retrieving Results for Index 10: Big Creek No. 3 Powerplant.
# ------------
# Retrieving Results for Index 11: Holm Powerhouse.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 12: Pine Flat Dam.
# ------------
# Retrieving Results for Index 13: Judge Francis Carr Powerhouse*.
# ------------
# Retrieving Results for Index 14: Camino Powerplant.
# ------------
# Retrieving Results for Index 15: Jaybird Powerplant.
# ------------
# Retrieving Results for Index 16: Poe Dam.
# ------------
# Retrieving Results for Index 17: (Poe Powerhouse).
# ------------
# Retrieving Results for Index 18: Trinity Dam.
# ------------
# Retrieving Results for Index 19: Belden Powerhouse.
# ------------
# Retrieving Results for Index 20: O'Shaughnessy Dam/Kirkwood Powerhouse.
# ------------
# Retrieving Results for Index 21: Caribou No. 1 Powerhouse.
# ------------
# Retrieving Results for Index 22: Parker Dam.
# ------------
# Retrieving Results for Index 23: Thermalito Power Plant.
# ------------
# Retrieving Results for Index 24: Keswick Dam.
# ------------
# Retrieving Results for Index 25: Rock Creek Powerhouse.
# ------------
# Retrieving Results for Index 26: Big Creek Powerplant 2A.
# ------------
# Retrieving Results for Index 27: Moccasin Powerplant.
# ------------
# Retrieving Results for Index 28: Big Creek Powerplant No. 4.
# ------------
# Retrieving Results for Index 29: New Exchequer Dam.
# ------------
# Retrieving Results for Index 30: Big Creek Powerplant No. 1.
# ------------
# Retrieving Results for Index 31: Loon Lake Powerplant.
# ------------
# Retrieving Results for Index 32: Big Creek Powerplant No. 8.
# ------------
# Retrieving Results for Index 33: Caribou No. 1 Powerhouse.
# ------------
# Retrieving Results for Index 34: Cresta Powerhouse.
# ------------
# Retrieving Results for Index 35: Big Creek Powerplant No. 2.
# ------------
# Retrieving Results for Index 36: Union Valley Dam.
# ------------
# Retrieving Results for Index 37: Lake Almanor Dam.
# ------------
# Retrieving Results for Index 38: (Butt Valley Powerhouse).
# ------------
# Retrieving Results for Index 39: Robbs Peak Powerhouse.
# ------------
# Retrieving Results for Index 40: Jones Fork Powerhouse.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 41: Monticello Dam.
# ------------
# Retrieving Results for Index 42: Portal Powerplant.
# ------------
# Retrieving Results for Index 43: Indian Valley Dam.
# ------------
# Retrieving Results for Index 44: Slab Creek Dam.
# ------------
# Retrieving Results for Index 45: Division Creek Power Plant Unit 2.
# Missing field/result... skipping.
# ------------

# %%
ca_dams_df.head()
# Out:
#                     Name      lat      lng
# 0             Shasta Dam   40.717 -122.418
# 1           Oroville Dam  39.5429 -121.492
# 2   New Bullards Bar Dam  39.4395 -121.134
# 3        New Melones Dam  37.9879 -120.535
# 4  White Rock Powerplant  38.6271 -121.092

# %%
### Loop Through Winds in WA ####

base_url = "https://maps.googleapis.com/maps/api/geocode/json"
params = {
    "location": "39.952583,-75.16522",  # philadelphia coords,
    "rankby": "distance",
    "type": "restaurant",
    "key": gkey,
}

# use iterrows to iterate through pandas dataframe
for index, row in wa_wind_df.iterrows():

    # get restaurant type from df
    restr_type = row['Name']

    # add keyword to params dict
    params["address"] = restr_type

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {restr_type}.")
    response = requests.get(base_url, params=params)
    
    dc_geo = response.json()
    
    try:
                
        wa_wind_df.loc[index, 'lat'] = dc_geo["results"][0]["geometry"]["location"]["lat"]
        wa_wind_df.loc[index, 'lng'] = dc_geo["results"][0]["geometry"]["location"]["lng"]

    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
    
### Loop Through Winds in CA ####

base_url = "https://maps.googleapis.com/maps/api/geocode/json"
params = {
    "location": "39.952583,-75.16522",  # philadelphia coords,
    "rankby": "distance",
    "type": "restaurant",
    "key": gkey,
}

# use iterrows to iterate through pandas dataframe
for index, row in ca_wind_df.iterrows():

    # get restaurant type from df
    restr_type = row['Name']

    # add keyword to params dict
    params["address"] = restr_type

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {restr_type}.")
    response = requests.get(base_url, params=params)
    
    dc_geo = response.json()
    
    try:
                
        ca_wind_df.loc[index, 'lat'] = dc_geo["results"][0]["geometry"]["location"]["lat"]
        ca_wind_df.loc[index, 'lng'] = dc_geo["results"][0]["geometry"]["location"]["lng"]

    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
# Out:
# Retrieving Results for Index 0: Wild Horse Wind Farm.
# ------------
# Retrieving Results for Index 1: Marengo Wind Farm.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 2: White Creek Wind Farm.
# ------------
# Retrieving Results for Index 3: Big Horn Wind Farm.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 4: Stateline Wind Farm.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 5: Hopkins Ridge Wind Farm.
# ------------
# Retrieving Results for Index 6: Harvest Wind Farm.
# ------------
# Retrieving Results for Index 7: Nine Canyon Wind Farm.
# ------------
# Retrieving Results for Index 8: Goodnoe Hills Wind Farm.
# ------------
# Retrieving Results for Index 9: Windy Flats.
# ------------
# Retrieving Results for Index 10: Coastal Energy.
# ------------
# Retrieving Results for Index 11: Lower Snake River Wind Project.
# ------------
# Retrieving Results for Index 12: Juniper Canyon.
# ------------
# Retrieving Results for Index 13: Kittitas Valley Wind Farm.
# ------------
# Retrieving Results for Index 14: Vantage Wind Power Project.
# ------------
# Retrieving Results for Index 15: Big Horn 2.
# ------------
# Retrieving Results for Index 16: Linden Ranch.
# ------------
# Retrieving Results for Index 17: Windy Point.
# ------------
# Retrieving Results for Index 18: Tucannon River Wind Farm.
# ------------
# Retrieving Results for Index 19: Swauk Valley Ranch Wind.
# ------------
# Retrieving Results for Index 0: Alta Wind Energy Center.
# ------------
# Retrieving Results for Index 1: Tehachapi Pass Wind Farm.
# ------------
# Retrieving Results for Index 2: San Gorgonio Pass Wind Farm.
# ------------
# Retrieving Results for Index 3: Altamont Pass Wind Farm.
# ------------
# Retrieving Results for Index 4: Ocotillo Wind Energy Facility*.
# ------------
# Retrieving Results for Index 5: Tule Wind Energy Project[22].
# ------------
# Retrieving Results for Index 6: Shiloh Wind Power Plant.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 7: Kumeyaay Wind farm.
# ------------

# %%
wa_wind_df.head()
# Out:
#                     Name      lat      lng
# 0   Wild Horse Wind Farm  46.9775  -120.21
# 1      Marengo Wind Farm
# 2  White Creek Wind Farm  45.8141 -120.347
# 3     Big Horn Wind Farm
# 4    Stateline Wind Farm

# %%
# Geolocation of Washington Dams
wd_locations = wa_dams_df[["lat", "lng"]]

# Geolocation of Washington Wind Power Plants
ww_locations = wa_wind_df[["lat", "lng"]]

# Geolocation of California Dams
cd_locations = ca_dams_df[["lat", "lng"]]

# Geolocation of California Wind Power Plants
cw_locations = ca_wind_df[["lat", "lng"]]
# Out:
#         lat      lng
# 0   46.9775  -120.21
# 1
# 2   45.8141 -120.347
# 3
# 4
# 5   46.3145 -117.988
# 6   45.8141 -120.347
# 7   46.1299 -119.037
# 8   45.7512  -120.48
# 9   37.9613 -122.329
# 10  44.2918   -68.29
# 11  44.6174 -114.647
# 12  32.2622 -110.996
# 13  47.1406 -120.716
# 14  46.9775  -120.21
# 15  44.8363 -108.403
# 16  44.6504  15.1594
# 17  30.4164 -97.8989
# 18  46.4709 -117.947
# 19  47.1247 -120.736

# %%
# Plot Headmap of Washington Dams on Google Map

# Plot Heatmap
wd_fig = gmaps.figure()

# Create heat layer
dam_layer = gmaps.heatmap_layer(wd_locations, 
                                 dissipating=False, max_intensity=5,
                                 point_radius=0.1)
# Add layer
wd_fig.add_layer(dam_layer)

wd_fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Plot Headmap of Washington Dams on Google Map

# Plot Heatmap
cd_fig = gmaps.figure()

# Create heat layer
dam_layer = gmaps.heatmap_layer(cd_locations, 
                                 dissipating=False, max_intensity=5,
                                 point_radius=0.1)
# Add layer
cd_fig.add_layer(dam_layer)

cd_fig
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/junge011/anaconda/lib/python3.6/site-packages/gmaps/geotraitlets.py in _validate_latitude(latitude)
#     274     try:
# --> 275         latitude = float(latitude)
#     276     except (TypeError, ValueError):
#
# ValueError: could not convert string to float:
#
# During handling of the above exception, another exception occurred:
#
# TraitError                                Traceback (most recent call last)
# <ipython-input-40-41f9d939469f> in <module>()
#       7 dam_layer = gmaps.heatmap_layer(cd_locations,
#       8                                  dissipating=False, max_intensity=5,
# ----> 9                                  point_radius=0.1)
#      10 # Add layer
#      11 cd_fig.add_layer(dam_layer)
#
# /Users/junge011/anaconda/lib/python3.6/site-packages/gmaps/heatmap.py in heatmap_layer(locations, weights, max_intensity, dissipating, point_radius, opacity, gradient)
#     269         return WeightedHeatmap(**widget_args)
#     270     else:
# --> 271         return Heatmap(**widget_args)
#
# /Users/junge011/anaconda/lib/python3.6/site-packages/ipywidgets/widgets/widget.py in __init__(self, **kwargs)
#     409         """Public constructor"""
#     410         self._model_id = kwargs.pop('model_id', None)
# --> 411         super(Widget, self).__init__(**kwargs)
#     412
#     413         Widget._call_widget_constructed(self)
#
# /Users/junge011/anaconda/lib/python3.6/site-packages/traitlets/traitlets.py in __init__(self, *args, **kwargs)
#     995             for key, value in kwargs.items():
#     996                 if self.has_trait(key):
# --> 997                     setattr(self, key, value)
#     998                 else:
#     999                     # passthrough args that don't set traits to super
#
# /Users/junge011/anaconda/lib/python3.6/site-packages/traitlets/traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# /Users/junge011/anaconda/lib/python3.6/site-packages/traitlets/traitlets.py in set(self, obj, value)
#     557
#     558     def set(self, obj, value):
# --> 559         new_value = self._validate(obj, value)
#     560         try:
#     561             old_value = obj._trait_values[self.name]
#
# /Users/junge011/anaconda/lib/python3.6/site-packages/traitlets/traitlets.py in _validate(self, obj, value)
#     589             return value
#     590         if hasattr(self, 'validate'):
# --> 591             value = self.validate(obj, value)
#     592         if obj._cross_validation_lock is False:
#     593             value = self._cross_validate(obj, value)
#
# /Users/junge011/anaconda/lib/python3.6/site-packages/gmaps/geotraitlets.py in validate(self, obj, value)
#      25         for location in locations_as_list:
#      26             latitude, longitude = location
# ---> 27             _validate_latitude(latitude)
#      28             _validate_longitude(longitude)
#      29         return super(LocationArray, self).validate(obj, locations_as_list)
#
# /Users/junge011/anaconda/lib/python3.6/site-packages/gmaps/geotraitlets.py in _validate_latitude(latitude)
#     277         raise traitlets.TraitError(
#     278             '{} is not a valid latitude. '
# --> 279             'Latitudes must be floats'.format(latitude)
#     280         )
#     281     if not (-90.0 <= latitude <= 90.0):
#
# TraitError:  is not a valid latitude. Latitudes must be floats
