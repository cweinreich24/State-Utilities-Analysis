# %%
import json
import requests
import pandas as pd
from weather_api import noa_key

from pprint import pprint

# %%
noa_key
# Out:
# 'QXnCvuxkdzVTqgmOlBXNdyVwFnRmCrqg'

# %%
states = json.loads(open("Data/52_states.json").read())
states
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 51, 'limit': 52}},
#  'results': [{'mindate': '1888-02-01',
#    'maxdate': '2018-08-04',
#    'name': 'Alabama',
#    'datacoverage': 1,
#    'id': 'FIPS:01'},
#   {'mindate': '1893-09-01',
#    'maxdate': '2018-08-04',
#    'name': 'Alaska',
#    'datacoverage': 1,
#    'id': 'FIPS:02'},
#   {'mindate': '1867-08-01',
#    'maxdate': '2018-08-04',
#    'name': 'Arizona',
#    'datacoverage': 1,
#    'id': 'FIPS:04'},
#   {'mindate': '1872-02-01',
#    'maxdate': '2018-08-04',
#    'name': 'Arkansas',
#    'datacoverage': 1,
#    'id': 'FIPS:05'},
#   {'mindate': '1850-10-01',
#    'maxdate': '2018-08-04',
#    'name': 'California',
#    'datacoverage': 1,
#    'id': 'FIPS:06'},
#   {'mindate': '1852-10-01',
#    'maxdate': '2018-08-04',
#    'name': 'Colorado',
#    'datacoverage': 1,
#    'id': 'FIPS:08'},
#   {'mindate': '1884-11-01',
#    'maxdate': '2018-08-04',
#    'name': 'Connecticut',
#    'datacoverage': 1,
# ...

# %%
datasets = json.loads(open("Data/datasets.json").read())
datasets
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 11, 'limit': 25}},
#  'results': [{'uid': 'gov.noaa.ncdc:C00861',
#    'mindate': '1763-01-01',
#    'maxdate': '2018-08-03',
#    'name': 'Daily Summaries',
#    'datacoverage': 1,
#    'id': 'GHCND'},
#   {'uid': 'gov.noaa.ncdc:C00946',
#    'mindate': '1763-01-01',
#    'maxdate': '2018-06-01',
#    'name': 'Global Summary of the Month',
#    'datacoverage': 1,
#    'id': 'GSOM'},
#   {'uid': 'gov.noaa.ncdc:C00947',
#    'mindate': '1763-01-01',
#    'maxdate': '2018-01-01',
#    'name': 'Global Summary of the Year',
#    'datacoverage': 1,
#    'id': 'GSOY'},
#   {'uid': 'gov.noaa.ncdc:C00345',
#    'mindate': '1991-06-05',
#    'maxdate': '2018-08-03',
#    'name': 'Weather Radar (Level II)',
#    'datacoverage': 0.95,
#    'id': 'NEXRAD2'},
#   {'uid': 'gov.noaa.ncdc:C00708',
#    'mindate': '1994-05-20',
#    'maxdate': '2018-07-26',
#    'name': 'Weather Radar (Level III)',
#    'datacoverage': 0.95,
#    'id': 'NEXRAD3'},
# ...

# %%
CA = json.loads(open("Data/california.json").read())
CA
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 7, 'limit': 25}},
#  'results': [{'uid': 'gov.noaa.ncdc:C00861',
#    'mindate': '1763-01-01',
#    'maxdate': '2018-08-03',
#    'name': 'Daily Summaries',
#    'datacoverage': 1,
#    'id': 'GHCND'},
#   {'uid': 'gov.noaa.ncdc:C00946',
#    'mindate': '1763-01-01',
#    'maxdate': '2018-06-01',
#    'name': 'Global Summary of the Month',
#    'datacoverage': 1,
#    'id': 'GSOM'},
#   {'uid': 'gov.noaa.ncdc:C00947',
#    'mindate': '1763-01-01',
#    'maxdate': '2018-01-01',
#    'name': 'Global Summary of the Year',
#    'datacoverage': 1,
#    'id': 'GSOY'},
#   {'uid': 'gov.noaa.ncdc:C00345',
#    'mindate': '1991-06-05',
#    'maxdate': '2018-08-03',
#    'name': 'Weather Radar (Level II)',
#    'datacoverage': 0.95,
#    'id': 'NEXRAD2'},
#   {'uid': 'gov.noaa.ncdc:C00708',
#    'mindate': '1994-05-20',
#    'maxdate': '2018-07-26',
#    'name': 'Weather Radar (Level III)',
#    'datacoverage': 0.95,
#    'id': 'NEXRAD3'},
# ...
